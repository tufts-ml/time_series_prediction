# %%
import pandas as pd
import os
import numpy as np
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LassoCV, RidgeCV, Lasso
from sklearn.metrics import mean_absolute_error, mean_squared_error, r2_score
from sklearn.model_selection import GridSearchCV, KFold
from sklearn.pipeline import Pipeline
from sklearn.preprocessing import StandardScaler, MaxAbsScaler
import time
from collections import OrderedDict
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %%
preproc_files_dir = '/cluster/tufts/hugheslab/prath01/projects/MASTRE/datasets'
static_df = pd.read_csv(os.path.join(preproc_files_dir, 'static_features.csv'))
highfreq_df = pd.read_csv(os.path.join(preproc_files_dir, 'highfreq_features.csv'))
session_outcomes_df = pd.read_csv(os.path.join(preproc_files_dir, 'session_level_marksmanship_outcomes.csv'))

# %%
y_pre_df = session_outcomes_df[session_outcomes_df.mission_phase=='PRE'].copy().reset_index(drop=True)
y_mid_df = session_outcomes_df[session_outcomes_df.mission_phase=='MID'].copy().reset_index(drop=True)
y_post1_df = session_outcomes_df[session_outcomes_df.mission_phase=='POST1'].copy().reset_index(drop=True)
y_post2_df = session_outcomes_df[session_outcomes_df.mission_phase=='POST2'].copy().reset_index(drop=True)
y_post3_df = session_outcomes_df[session_outcomes_df.mission_phase=='POST3'].copy().reset_index(drop=True)


keep_ids = list(set(static_df.subject_uid) & 
                set(highfreq_df.subject_uid) & 
                set(y_post1_df.subject_uid) &
               set(y_post2_df.subject_uid) &
               set(y_post3_df.subject_uid))

static_df = static_df.loc[static_df.subject_uid.isin(keep_ids), :].copy().reset_index(drop=True)
highfreq_df = highfreq_df.loc[highfreq_df.subject_uid.isin(keep_ids), :].copy().reset_index(drop=True)

# define y's
y_pre_df = y_pre_df.loc[y_pre_df.subject_uid.isin(keep_ids), :].copy().reset_index(drop=True)
y_mid_df = y_mid_df.loc[y_mid_df.subject_uid.isin(keep_ids), :].copy().reset_index(drop=True)
y_post1_df = y_post1_df.loc[y_post1_df.subject_uid.isin(keep_ids), :].copy().reset_index(drop=True)
y_post2_df = y_post2_df.loc[y_post2_df.subject_uid.isin(keep_ids), :].copy().reset_index(drop=True)
y_post3_df = y_post3_df.loc[y_post3_df.subject_uid.isin(keep_ids), :].copy().reset_index(drop=True)

# define static features
non_missing_static_df = static_df.loc[:,(~static_df.isnull()).all(axis=0)].copy().reset_index(drop=True)
non_missing_static_df.replace({'yes':1, 'no':0}, inplace=True)

# define highfrequency features
shot_location_over_sessions_df = highfreq_df.groupby(['subject_uid', 'mission_phase'],
                                                     as_index=False).median()[['subject_uid', 'mission_phase',
                                                                               'shot_x_75', 'shot_y_75']]
highfreq_pre_df = shot_location_over_sessions_df.loc[shot_location_over_sessions_df.mission_phase=='PRE',
                                                        ['shot_x_75', 'shot_y_75']].reset_index(drop=True)
highfreq_mid_df = shot_location_over_sessions_df.loc[shot_location_over_sessions_df.mission_phase=='MID',
                                                        ['shot_x_75', 'shot_y_75']].reset_index(drop=True)
highfreq_post1_df = shot_location_over_sessions_df.loc[shot_location_over_sessions_df.mission_phase=='POST1',
                                                        ['shot_x_75', 'shot_y_75']].reset_index(drop=True)
highfreq_post2_df = shot_location_over_sessions_df.loc[shot_location_over_sessions_df.mission_phase=='POST2',
                                                        ['shot_x_75', 'shot_y_75']].reset_index(drop=True)

# %%
#------------------------------Multi Train - Test Lasso----------------------------#
def lasso_regression_multi_train_test_splits(
        X, y, n_trials, n_cv_folds,
        gridsearchvalues__alpha=np.logspace(-5, 5, 5),
        x_feature_transform='none',
        scoring_metric='mean_squared_error'):
    """ Perform nested cross-validation to train Lasso predictor given a fixed training set
    Returns
    -------
    best_regressor_per_trial : list
    perf_dict_per_trial : list
    """
    start_time_sec = time.time()

    print("Fitting Lasso with %d trials of %d-fold nested cross validation" % (
        n_trials, n_cv_folds))

    # Parameter grid to consider on each inner heldout fold
    if isinstance(gridsearchvalues__alpha, str):
        if gridsearchvalues__alpha.count("logspace"):
            gsv = gridsearchvalues__alpha.replace("logspace", "")
            gsv = gsv.replace("(", "")
            gsv = gsv.replace(")", "")
            amin, amax, anum = map(float, gsv.split(','))
            anum = int(anum)
            alpha_grid = np.logspace(amin, amax, anum).astype(np.float64)
        elif gridsearchvalues__alpha.count("linspace"):
            gsv = gridsearchvalues__alpha.replace("linspace", "")
            gsv = gsv.replace("(", "")
            gsv = gsv.replace(")", "")
            amin, amax, anum = map(float, gsv.split(','))
            anum = int(anum)
            alpha_grid = np.linspace(amin, amax, anum).astype(np.float64)
        else:
            alpha_grid = np.asarray(
                list(map(float, gridsearchvalues__alpha.split(","))),
                dtype=np.float64)
    else:
        alpha_grid = np.asarray(gridsearchvalues__alpha, dtype=np.float64)
    alpha_str = ','.join(['%.3g' % a for a in alpha_grid[:3]])
    if alpha_grid.size > 5:
        alpha_str += ',' + '...'
    if alpha_grid.size > 3:
        M = np.maximum(3, alpha_grid.size - 2)
        alpha_str += ',' + ','.join(['%.3g' % a for a in alpha_grid[M:]])
    print("Selecting parameter 'alpha' based on grid search over %d param values:\n%s" % (
        alpha_grid.size, alpha_str))
    param_grid = [{'regressor__alpha': alpha_grid}]
    
    # Arrays to store scores
    best_regressors = [None for _ in range(n_trials)]
    outer_perf_dict_list = [None for _ in range(n_trials)]
    inner_perf_df_list = [None for _ in range(n_trials)]
    
    # Loop for each trial
    for i in range(n_trials):
      
        # Perform OUTER train-test split
        # If we use a test size of 1/(K+1)
        # Then we'll get heldout folds of the same size as the inner heldout folds with K-fold CV
        # Why?
        # Outer fold takes 1/(K+1) of N examples
        # Inner fold takes 1/K of ( K/(K+1) * N ) examples = 1/(K+1) * N
        X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=(1.0/(1+n_cv_folds)), random_state=i)  

        # create a cv splitter object 
        inner_cv_splitter = KFold(n_splits=n_cv_folds, shuffle=True, random_state=i)
        
        # STEP 1 in pipeline: 
        step_list = list()
        if x_feature_transform.startswith('standardize'):
            ## Scale the input features to have zero mean/unit variance
            scaler_x = StandardScaler()
            step_list.append(('standardize', scaler_x))
        elif x_feature_transform == 'scale_0_to_1':
            ## Scale the input features to have min zero and max one
            scaler_x = MaxAbsScaler()
            step_list.append(('scale_0_to_1', scaler_x))
        elif x_feature_transform == 'none':
            pass
        else:
            raise ValueError("Unrecognized value: 'x_feature_transform'=%s" % x_feature_transform)
        
        # STEP 2 in pipeline: Define the predictor from input to output
        step_list.append(('regressor', Lasso(max_iter=1000000, tol=0.001, selection='cyclic')))

        ## Create Pipeline regressor as composition of steps
        prediction_pipeline = Pipeline(step_list)

        ## Prepare for n-fold cross validation
        if scoring_metric == 'mean_absolute_error':
            scoring = 'neg_mean_absolute_error'
            baseline_func = np.median
        elif scoring_metric == 'mean_squared_error':
            scoring = 'neg_mean_squared_error'
            baseline_func = np.mean
        else:
            raise ValueError("Unrecognized value: 'scoring_metric'=%s" % scoring_metric)

        regressor_with_grid_search = GridSearchCV(
                prediction_pipeline, param_grid,
                cv=inner_cv_splitter,
                scoring=scoring,
                return_train_score=True,
                iid=False, refit=True)
        regressor_with_grid_search.fit(X_train, y_train)

        best_i = regressor_with_grid_search.best_index_
        inner_cv_df = pd.DataFrame(regressor_with_grid_search.cv_results_)
        perf_at_best_df = inner_cv_df.iloc[best_i:(best_i+1)].copy()

        best_regressors[i] = regressor_with_grid_search.best_estimator_
        outer_train_score = regressor_with_grid_search.score(X_train, y_train)
        outer_test_score = regressor_with_grid_search.score(X_test, y_test)
        cur_perf = OrderedDict()
        cur_perf['trial_id'] = i
        for mname, metric_func in [
                ('mse', mean_squared_error),
                ('mae', mean_absolute_error)
                ]:
            yhat_train = best_regressors[i].predict(X_train)
            yhat_test = best_regressors[i].predict(X_test)
            cur_perf['train_%s' % mname] = metric_func(y_train, yhat_train)
            cur_perf['test_%s' % mname] = metric_func(y_test, yhat_test)
        cur_perf['train_size'] = y_train.size
        cur_perf['test_size'] = y_test.size

        cur_perf['outer_train_score'] = -1 * outer_train_score
        cur_perf['outer_test_score'] = -1 * outer_test_score
        cur_perf['inner_mean_train_score'] = -1 * perf_at_best_df['mean_train_score'].values[0]
        cur_perf['inner_mean_test_score'] = -1 * perf_at_best_df['mean_test_score'].values[0]
        tr_vals = np.zeros(n_cv_folds)
        te_vals = np.zeros(n_cv_folds)
        for ss in range(n_cv_folds):
            key = 'split%d' % ss
            tr_vals[ss] = -1 * perf_at_best_df['%s_train_score' % key].values[0]
            te_vals[ss] = -1 * perf_at_best_df['%s_test_score' % key].values[0]
            cur_perf['inner_%s_train_score' % key] = tr_vals[ss]
            cur_perf['inner_%s_test_score' % key] = te_vals[ss]
        for fname, func in [('min', np.min), ('max', np.max)]:
            cur_perf['inner_%s_train_score' % fname] = func(tr_vals)
            cur_perf['inner_%s_test_score' % fname] = func(te_vals)
        outer_perf_dict_list[i] = cur_perf

        cur_perf['outer_model_bias'] = best_regressors[i]['regressor'].intercept_
        cur_perf['outer_model_num_nonzero_coef'] = np.sum(np.abs(best_regressors[i]['regressor'].coef_) > 1e-8)

        for key in sorted(regressor_with_grid_search.best_params_.keys()):
            cur_perf['outer_model_best_param__%s' % key] = regressor_with_grid_search.best_params_[key]

        outer_perf_dict_list[i] = cur_perf
        inner_perf_df_list[i] = inner_cv_df

        print("completed trial %3d/%d after %8.0f sec | tr score %8.3f | te score %8.3f | nnz %6d" % (
            i + 1, n_trials, time.time() - start_time_sec, 
            cur_perf['outer_train_score'],
            cur_perf['outer_test_score'],
            cur_perf['outer_model_num_nonzero_coef'],
            ))

    outer_perf_df = pd.DataFrame(outer_perf_dict_list)
    return best_regressors, outer_perf_df, inner_perf_df_list

# %% [markdown]
# ## predict post3 with past y factors
#
# This includes 4 scenarios:
# - predicting performance on post3 with only pre-mission performance
# - predicting performance on post3 with only pre-mission, post1 mission
# - predicting performance on post3 with only pre-mission, post1 mission, post2 mission
# - predicting performance on post3 with only pre-mission, post1 mission, post2 mission and X-factors

# %%
n_trials = 20
n_cv_folds = 10
row_df_list = list()
for y_factor in ['lethality', 'mobility', 'stability']:
    X_pre = np.asarray(y_pre_df[y_factor], dtype=np.float64).reshape(-1,1)
    X_pre_mid = np.asarray([y_pre_df[y_factor], y_mid_df[y_factor]], dtype=np.float64).T
    X_pre_mid_post1 = np.asarray([y_pre_df[y_factor], y_mid_df[y_factor], y_post1_df[y_factor]], dtype=np.float64).T
    X_pre_mid_post1_post2 = np.asarray([y_pre_df[y_factor], y_mid_df[y_factor], 
                                        y_post1_df[y_factor], y_post2_df[y_factor]], dtype=np.float64).T
    X_static_pre_mid_post1_post2 = np.asarray(np.concatenate((non_missing_static_df.values, 
                                                              y_pre_df[y_factor].values.reshape(-1,1),
                                                              y_mid_df[y_factor].values.reshape(-1,1),
                                                              y_post1_df[y_factor].values.reshape(-1,1), 
                                                              y_post2_df[y_factor].values.reshape(-1,1)), axis=1), 
                                              dtype=np.float64)
    
    X_highfreq_pre_mid_post1_post2 = np.asarray(np.concatenate((highfreq_pre_df.values,
                                                                highfreq_mid_df.values,
                                                                highfreq_post1_df.values,
                                                                highfreq_post2_df.values,
                                                              y_pre_df[y_factor].values.reshape(-1,1),
                                                              y_mid_df[y_factor].values.reshape(-1,1),
                                                              y_post1_df[y_factor].values.reshape(-1,1), 
                                                              y_post2_df[y_factor].values.reshape(-1,1)), axis=1), 
                                              dtype=np.float64)
    
    y_out = np.asarray(y_post3_df[y_factor], dtype=np.float64)
    perc_vals = [5, 50, 95]

    
    for X,y,feature_nickname in [(X_pre, y_out, 'pre'), 
                                 (X_pre_mid, y_out, 'pre+mid'),
                                 (X_pre_mid_post1, y_out, 'pre+mid+post1'), 
                                 (X_pre_mid_post1_post2, y_out, 'pre+mid+post1+post2'), 
                                 (X_static_pre_mid_post1_post2, y_out, 'static+pre+mid+post1+post2'),
#                                  (X_highfreq_pre_mid_post1_post2, y_out, 'highfreq+pre+mid+post1+post2')
                                ]:
        print('Predicting %s with %s as predictors'%(y_factor, feature_nickname))
        best_regressors, outer_perf_df, inner_perf_df_list = lasso_regression_multi_train_test_splits(X, y, 
                                                                                                      n_trials, n_cv_folds,
                                                                                                      gridsearchvalues__alpha=np.logspace(-12, 6, 37),
                                                                                                      x_feature_transform='standardize',
                                                                                                      scoring_metric='mean_absolute_error')

        for perc in perc_vals:
            row_df = pd.DataFrame(
                [np.percentile(outer_perf_df.values[:, 1:], perc, axis=0)],
                columns=outer_perf_df.columns[1:])
            row_df.insert(0, 'y_column', y_factor)
            row_df.insert(1, 'x_feature_nickname', feature_nickname)
            row_df.insert(2, 'n_features', X.shape[1])
            row_df.insert(3, 'percentile_across_trials', perc)
            row_df_list.append(row_df)
summary_perf_df = pd.concat(row_df_list, ignore_index=True)
# Out:
# Predicting lethality with pre as predictors
# Fitting Lasso with 20 trials of 10-fold nested cross validation
# Selecting parameter 'alpha' based on grid search over 37 param values:
# 1e-12,3.16e-12,1e-11,...,3.16e+05,1e+06
# completed trial   1/20 after        1 sec | tr score   27.566 | te score   46.429 | nnz      0
# completed trial   2/20 after        2 sec | tr score   31.586 | te score   18.345 | nnz      0
# completed trial   3/20 after        3 sec | tr score   29.241 | te score   36.130 | nnz      0
# completed trial   4/20 after        4 sec | tr score   29.130 | te score   34.629 | nnz      0
# completed trial   5/20 after        6 sec | tr score   31.890 | te score   16.326 | nnz      0
# completed trial   6/20 after        7 sec | tr score   30.916 | te score   23.310 | nnz      0
# completed trial   7/20 after        8 sec | tr score   30.409 | te score   30.258 | nnz      0
# completed trial   8/20 after        9 sec | tr score   28.617 | te score   39.217 | nnz      0
# completed trial   9/20 after       10 sec | tr score   28.088 | te score   42.930 | nnz      0
# completed trial  10/20 after       11 sec | tr score   27.831 | te score   43.398 | nnz      0
# completed trial  11/20 after       12 sec | tr score   30.202 | te score   26.865 | nnz      0
# completed trial  12/20 after       13 sec | tr score   31.964 | te score   15.830 | nnz      0
# completed trial  13/20 after       15 sec | tr score   29.981 | te score   28.197 | nnz      0
# completed trial  14/20 after       16 sec | tr score   30.634 | te score   26.617 | nnz      0
# completed trial  15/20 after       17 sec | tr score   32.174 | te score   11.602 | nnz      0
# completed trial  16/20 after       18 sec | tr score   30.754 | te score   24.948 | nnz      0
# completed trial  17/20 after       19 sec | tr score   30.091 | te score   28.101 | nnz      0
# completed trial  18/20 after       20 sec | tr score   31.798 | te score   15.953 | nnz      0
# completed trial  19/20 after       21 sec | tr score   30.548 | te score   21.824 | nnz      0
# completed trial  20/20 after       22 sec | tr score   30.377 | te score   24.465 | nnz      0
# Predicting lethality with pre+mid as predictors
# Fitting Lasso with 20 trials of 10-fold nested cross validation
# Selecting parameter 'alpha' based on grid search over 37 param values:
# 1e-12,3.16e-12,1e-11,...,3.16e+05,1e+06
# completed trial   1/20 after        1 sec | tr score   27.566 | te score   46.429 | nnz      0
# completed trial   2/20 after        2 sec | tr score   31.586 | te score   18.345 | nnz      0
# completed trial   3/20 after        3 sec | tr score   29.241 | te score   36.130 | nnz      0
# completed trial   4/20 after        5 sec | tr score   29.130 | te score   34.629 | nnz      0
# completed trial   5/20 after        6 sec | tr score   31.890 | te score   16.326 | nnz      0
# completed trial   6/20 after        7 sec | tr score   30.916 | te score   23.310 | nnz      0
# completed trial   7/20 after        8 sec | tr score   30.409 | te score   30.258 | nnz      0
# completed trial   8/20 after        9 sec | tr score   28.617 | te score   39.217 | nnz      0
# completed trial   9/20 after       10 sec | tr score   28.088 | te score   42.930 | nnz      0
# completed trial  10/20 after       11 sec | tr score   27.831 | te score   43.398 | nnz      0
# completed trial  11/20 after       13 sec | tr score   30.202 | te score   26.865 | nnz      0
# completed trial  12/20 after       14 sec | tr score   31.964 | te score   15.830 | nnz      0
# completed trial  13/20 after       15 sec | tr score   29.981 | te score   28.197 | nnz      0
# completed trial  14/20 after       16 sec | tr score   30.634 | te score   26.617 | nnz      0
# completed trial  15/20 after       17 sec | tr score   32.174 | te score   11.602 | nnz      0
# completed trial  16/20 after       18 sec | tr score   30.754 | te score   24.948 | nnz      0
# completed trial  17/20 after       19 sec | tr score   30.091 | te score   28.101 | nnz      0
# completed trial  18/20 after       20 sec | tr score   31.798 | te score   15.953 | nnz      0
# completed trial  19/20 after       22 sec | tr score   30.548 | te score   21.824 | nnz      0
# completed trial  20/20 after       23 sec | tr score   30.377 | te score   24.465 | nnz      0
# Predicting lethality with pre+mid+post1 as predictors
# Fitting Lasso with 20 trials of 10-fold nested cross validation
# Selecting parameter 'alpha' based on grid search over 37 param values:
# 1e-12,3.16e-12,1e-11,...,3.16e+05,1e+06
# completed trial   1/20 after        1 sec | tr score   27.566 | te score   46.429 | nnz      0
# completed trial   2/20 after        2 sec | tr score   31.586 | te score   18.345 | nnz      0
# completed trial   3/20 after        3 sec | tr score   29.241 | te score   36.130 | nnz      0
# completed trial   4/20 after        5 sec | tr score   29.130 | te score   34.629 | nnz      0
# completed trial   5/20 after        6 sec | tr score   31.890 | te score   16.326 | nnz      0
# completed trial   6/20 after        7 sec | tr score   30.916 | te score   23.310 | nnz      0
# completed trial   7/20 after        8 sec | tr score   30.409 | te score   30.258 | nnz      0
# completed trial   8/20 after        9 sec | tr score   28.617 | te score   39.217 | nnz      0
# completed trial   9/20 after       10 sec | tr score   28.088 | te score   42.930 | nnz      0
# completed trial  10/20 after       11 sec | tr score   27.831 | te score   43.398 | nnz      0
# completed trial  11/20 after       13 sec | tr score   30.202 | te score   26.865 | nnz      0
# completed trial  12/20 after       14 sec | tr score   31.964 | te score   15.830 | nnz      0
# completed trial  13/20 after       15 sec | tr score   29.981 | te score   28.197 | nnz      0
# completed trial  14/20 after       16 sec | tr score   30.634 | te score   26.617 | nnz      0
# completed trial  15/20 after       17 sec | tr score   32.174 | te score   11.602 | nnz      0
# completed trial  16/20 after       18 sec | tr score   30.754 | te score   24.948 | nnz      0
# completed trial  17/20 after       19 sec | tr score   30.091 | te score   28.101 | nnz      0
# completed trial  18/20 after       21 sec | tr score   31.798 | te score   15.953 | nnz      0
# completed trial  19/20 after       22 sec | tr score   30.548 | te score   21.824 | nnz      0
# completed trial  20/20 after       23 sec | tr score   30.377 | te score   24.465 | nnz      0
# Predicting lethality with pre+mid+post1+post2 as predictors
# Fitting Lasso with 20 trials of 10-fold nested cross validation
# Selecting parameter 'alpha' based on grid search over 37 param values:
# 1e-12,3.16e-12,1e-11,...,3.16e+05,1e+06
# completed trial   1/20 after        1 sec | tr score   23.838 | te score   35.556 | nnz      2
# completed trial   2/20 after        2 sec | tr score   23.510 | te score   29.482 | nnz      2
# completed trial   3/20 after        3 sec | tr score   26.993 | te score   24.356 | nnz      1
# completed trial   4/20 after        5 sec | tr score   26.314 | te score   25.527 | nnz      1
# completed trial   5/20 after        6 sec | tr score   27.844 | te score   12.069 | nnz      1
# completed trial   6/20 after        7 sec | tr score   27.146 | te score   16.761 | nnz      1
# completed trial   7/20 after        8 sec | tr score   23.867 | te score   37.673 | nnz      1
# completed trial   8/20 after        9 sec | tr score   24.945 | te score   34.514 | nnz      1
# completed trial   9/20 after       10 sec | tr score   25.936 | te score   32.300 | nnz      1
# completed trial  10/20 after       11 sec | tr score   25.598 | te score   32.504 | nnz      1
# completed trial  11/20 after       13 sec | tr score   25.917 | te score   25.211 | nnz      1
# completed trial  12/20 after       14 sec | tr score   25.516 | te score   15.567 | nnz      2
# completed trial  13/20 after       15 sec | tr score   24.844 | te score   22.542 | nnz      1
# completed trial  14/20 after       16 sec | tr score   22.943 | te score   32.112 | nnz      3
# completed trial  15/20 after       17 sec | tr score   25.620 | te score   22.472 | nnz      1
# completed trial  16/20 after       18 sec | tr score   25.935 | te score   13.632 | nnz      2
# completed trial  17/20 after       20 sec | tr score   24.385 | te score   24.543 | nnz      2
# completed trial  18/20 after       21 sec | tr score   27.219 | te score   13.085 | nnz      1
# completed trial  19/20 after       22 sec | tr score   25.268 | te score   18.202 | nnz      1
# completed trial  20/20 after       23 sec | tr score   25.437 | te score   17.141 | nnz      1
# Predicting lethality with static+pre+mid+post1+post2 as predictors
# Fitting Lasso with 20 trials of 10-fold nested cross validation
# Selecting parameter 'alpha' based on grid search over 37 param values:
# 1e-12,3.16e-12,1e-11,...,3.16e+05,1e+06
# completed trial   1/20 after        2 sec | tr score   25.084 | te score   40.112 | nnz      1
# completed trial   2/20 after        4 sec | tr score   24.488 | te score   24.954 | nnz      2
# completed trial   3/20 after        5 sec | tr score   26.993 | te score   24.356 | nnz      1
# completed trial   4/20 after        7 sec | tr score   24.847 | te score   28.274 | nnz      3
# completed trial   5/20 after        9 sec | tr score   27.795 | te score   11.879 | nnz      2
# completed trial   6/20 after       11 sec | tr score   26.638 | te score   15.927 | nnz      2
# completed trial   7/20 after       12 sec | tr score   23.137 | te score   38.464 | nnz      2
# completed trial   8/20 after       14 sec | tr score   24.716 | te score   35.677 | nnz      2
# completed trial   9/20 after       16 sec | tr score   25.909 | te score   32.339 | nnz      2
# completed trial  10/20 after       17 sec | tr score   24.624 | te score   33.737 | nnz      2
# completed trial  11/20 after       19 sec | tr score   25.459 | te score   25.112 | nnz      2
# completed trial  12/20 after       21 sec | tr score   26.701 | te score   14.803 | nnz      2
# completed trial  13/20 after       23 sec | tr score   25.921 | te score   24.282 | nnz      2
# completed trial  14/20 after       24 sec | tr score   24.874 | te score   29.327 | nnz      2
# completed trial  15/20 after       26 sec | tr score   25.309 | te score   21.035 | nnz      2
# completed trial  16/20 after       28 sec | tr score   26.947 | te score   15.071 | nnz      2
# completed trial  17/20 after       29 sec | tr score   25.747 | te score   23.319 | nnz      2
# completed trial  18/20 after       31 sec | tr score   26.856 | te score   12.913 | nnz      2
# completed trial  19/20 after       33 sec | tr score   26.455 | te score   19.393 | nnz      1
# completed trial  20/20 after       34 sec | tr score   25.804 | te score   20.164 | nnz      2
# Predicting mobility with pre as predictors
# Fitting Lasso with 20 trials of 10-fold nested cross validation
# Selecting parameter 'alpha' based on grid search over 37 param values:
# 1e-12,3.16e-12,1e-11,...,3.16e+05,1e+06
# completed trial   1/20 after        1 sec | tr score    0.181 | te score    0.285 | nnz      0
# completed trial   2/20 after        2 sec | tr score    0.183 | te score    0.291 | nnz      0
# completed trial   3/20 after        3 sec | tr score    0.193 | te score    0.173 | nnz      1
# completed trial   4/20 after        4 sec | tr score    0.198 | te score    0.167 | nnz      0
# completed trial   5/20 after        6 sec | tr score    0.208 | te score    0.111 | nnz      0
# completed trial   6/20 after        7 sec | tr score    0.191 | te score    0.233 | nnz      0
# completed trial   7/20 after        8 sec | tr score    0.186 | te score    0.233 | nnz      1
# completed trial   8/20 after        9 sec | tr score    0.198 | te score    0.176 | nnz      0
# completed trial   9/20 after       10 sec | tr score    0.199 | te score    0.160 | nnz      1
# completed trial  10/20 after       11 sec | tr score    0.207 | te score    0.121 | nnz      0
# completed trial  11/20 after       12 sec | tr score    0.164 | te score    0.407 | nnz      0
# completed trial  12/20 after       13 sec | tr score    0.198 | te score    0.223 | nnz      0
# completed trial  13/20 after       15 sec | tr score    0.189 | te score    0.218 | nnz      0
# completed trial  14/20 after       16 sec | tr score    0.177 | te score    0.270 | nnz      1
# completed trial  15/20 after       17 sec | tr score    0.192 | te score    0.194 | nnz      0
# completed trial  16/20 after       18 sec | tr score    0.200 | te score    0.196 | nnz      0
# completed trial  17/20 after       19 sec | tr score    0.177 | te score    0.328 | nnz      0
# completed trial  18/20 after       20 sec | tr score    0.200 | te score    0.195 | nnz      0
# completed trial  19/20 after       21 sec | tr score    0.195 | te score    0.251 | nnz      0
# completed trial  20/20 after       22 sec | tr score    0.188 | te score    0.249 | nnz      0
# Predicting mobility with pre+mid as predictors
# Fitting Lasso with 20 trials of 10-fold nested cross validation
# Selecting parameter 'alpha' based on grid search over 37 param values:
# 1e-12,3.16e-12,1e-11,...,3.16e+05,1e+06
# completed trial   1/20 after        1 sec | tr score    0.181 | te score    0.285 | nnz      0
# completed trial   2/20 after        2 sec | tr score    0.170 | te score    0.297 | nnz      2
# completed trial   3/20 after        3 sec | tr score    0.189 | te score    0.141 | nnz      2
# completed trial   4/20 after        5 sec | tr score    0.198 | te score    0.167 | nnz      0
# completed trial   5/20 after        6 sec | tr score    0.208 | te score    0.111 | nnz      0
# completed trial   6/20 after        7 sec | tr score    0.178 | te score    0.241 | nnz      2
# completed trial   7/20 after        8 sec | tr score    0.180 | te score    0.227 | nnz      2
# completed trial   8/20 after        9 sec | tr score    0.198 | te score    0.176 | nnz      0
# completed trial   9/20 after       10 sec | tr score    0.198 | te score    0.123 | nnz      2
# completed trial  10/20 after       11 sec | tr score    0.195 | te score    0.127 | nnz      2
# completed trial  11/20 after       13 sec | tr score    0.164 | te score    0.407 | nnz      0
# completed trial  12/20 after       14 sec | tr score    0.198 | te score    0.223 | nnz      0
# completed trial  13/20 after       15 sec | tr score    0.189 | te score    0.218 | nnz      0
# completed trial  14/20 after       16 sec | tr score    0.175 | te score    0.254 | nnz      2
# completed trial  15/20 after       17 sec | tr score    0.180 | te score    0.209 | nnz      2
# completed trial  16/20 after       18 sec | tr score    0.186 | te score    0.209 | nnz      2
# completed trial  17/20 after       19 sec | tr score    0.168 | te score    0.311 | nnz      2
# completed trial  18/20 after       21 sec | tr score    0.189 | te score    0.190 | nnz      2
# completed trial  19/20 after       22 sec | tr score    0.195 | te score    0.251 | nnz      0
# completed trial  20/20 after       23 sec | tr score    0.188 | te score    0.249 | nnz      0
# Predicting mobility with pre+mid+post1 as predictors
# Fitting Lasso with 20 trials of 10-fold nested cross validation
# Selecting parameter 'alpha' based on grid search over 37 param values:
# 1e-12,3.16e-12,1e-11,...,3.16e+05,1e+06
# completed trial   1/20 after        1 sec | tr score    0.143 | te score    0.196 | nnz      3
# completed trial   2/20 after        2 sec | tr score    0.133 | te score    0.270 | nnz      2
# completed trial   3/20 after        3 sec | tr score    0.148 | te score    0.175 | nnz      3
# completed trial   4/20 after        5 sec | tr score    0.150 | te score    0.158 | nnz      3
# completed trial   5/20 after        6 sec | tr score    0.154 | te score    0.117 | nnz      3
# completed trial   6/20 after        7 sec | tr score    0.152 | te score    0.160 | nnz      3
# completed trial   7/20 after        8 sec | tr score    0.143 | te score    0.187 | nnz      3
# completed trial   8/20 after        9 sec | tr score    0.152 | te score    0.124 | nnz      2
# completed trial   9/20 after       10 sec | tr score    0.141 | te score    0.195 | nnz      3
# completed trial  10/20 after       12 sec | tr score    0.162 | te score    0.047 | nnz      3
# completed trial  11/20 after       13 sec | tr score    0.126 | te score    0.320 | nnz      3
# completed trial  12/20 after       14 sec | tr score    0.152 | te score    0.180 | nnz      3
# completed trial  13/20 after       15 sec | tr score    0.157 | te score    0.126 | nnz      2
# completed trial  14/20 after       16 sec | tr score    0.148 | te score    0.182 | nnz      3
# completed trial  15/20 after       17 sec | tr score    0.137 | te score    0.218 | nnz      2
# completed trial  16/20 after       18 sec | tr score    0.156 | te score    0.130 | nnz      3
# completed trial  17/20 after       20 sec | tr score    0.137 | te score    0.265 | nnz      3
# completed trial  18/20 after       21 sec | tr score    0.153 | te score    0.145 | nnz      3
# completed trial  19/20 after       22 sec | tr score    0.157 | te score    0.098 | nnz      3
# completed trial  20/20 after       23 sec | tr score    0.139 | te score    0.218 | nnz      3
# Predicting mobility with pre+mid+post1+post2 as predictors
# Fitting Lasso with 20 trials of 10-fold nested cross validation
# Selecting parameter 'alpha' based on grid search over 37 param values:
# 1e-12,3.16e-12,1e-11,...,3.16e+05,1e+06
# completed trial   1/20 after        1 sec | tr score    0.125 | te score    0.171 | nnz      4
# completed trial   2/20 after        2 sec | tr score    0.116 | te score    0.269 | nnz      3
# completed trial   3/20 after        3 sec | tr score    0.135 | te score    0.127 | nnz      3
# completed trial   4/20 after        5 sec | tr score    0.137 | te score    0.123 | nnz      4
# completed trial   5/20 after        6 sec | tr score    0.137 | te score    0.113 | nnz      4
# completed trial   6/20 after        7 sec | tr score    0.126 | te score    0.211 | nnz      4
# completed trial   7/20 after        8 sec | tr score    0.127 | te score    0.142 | nnz      4
# completed trial   8/20 after        9 sec | tr score    0.129 | te score    0.180 | nnz      2
# completed trial   9/20 after       10 sec | tr score    0.142 | te score    0.131 | nnz      2
# completed trial  10/20 after       11 sec | tr score    0.146 | te score    0.091 | nnz      2
# completed trial  11/20 after       13 sec | tr score    0.112 | te score    0.268 | nnz      4
# completed trial  12/20 after       14 sec | tr score    0.132 | te score    0.181 | nnz      4
# completed trial  13/20 after       15 sec | tr score    0.137 | te score    0.119 | nnz      3
# completed trial  14/20 after       16 sec | tr score    0.135 | te score    0.202 | nnz      2
# completed trial  15/20 after       17 sec | tr score    0.131 | te score    0.135 | nnz      4
# completed trial  16/20 after       18 sec | tr score    0.134 | te score    0.162 | nnz      4
# completed trial  17/20 after       20 sec | tr score    0.122 | te score    0.250 | nnz      4
# completed trial  18/20 after       21 sec | tr score    0.137 | te score    0.147 | nnz      3
# completed trial  19/20 after       22 sec | tr score    0.143 | te score    0.117 | nnz      3
# completed trial  20/20 after       23 sec | tr score    0.119 | te score    0.230 | nnz      4
# Predicting mobility with static+pre+mid+post1+post2 as predictors
# Fitting Lasso with 20 trials of 10-fold nested cross validation
# Selecting parameter 'alpha' based on grid search over 37 param values:
# 1e-12,3.16e-12,1e-11,...,3.16e+05,1e+06
# completed trial   1/20 after        2 sec | tr score    0.106 | te score    0.289 | nnz      7
# completed trial   2/20 after        3 sec | tr score    0.086 | te score    0.268 | nnz     17
# completed trial   3/20 after        5 sec | tr score    0.166 | te score    0.135 | nnz      1
# completed trial   4/20 after        6 sec | tr score    0.092 | te score    0.249 | nnz     13
# completed trial   5/20 after        8 sec | tr score    0.122 | te score    0.148 | nnz     10
# completed trial   6/20 after        9 sec | tr score    0.158 | te score    0.225 | nnz      1
# completed trial   7/20 after       11 sec | tr score    0.115 | te score    0.162 | nnz      9
# completed trial   8/20 after       12 sec | tr score    0.102 | te score    0.261 | nnz      8
# completed trial   9/20 after       14 sec | tr score    0.122 | te score    0.167 | nnz     11
# completed trial  10/20 after       16 sec | tr score    0.125 | te score    0.115 | nnz     10
# completed trial  11/20 after       17 sec | tr score    0.147 | te score    0.377 | nnz      1
# completed trial  12/20 after       18 sec | tr score    0.167 | te score    0.209 | nnz      1
# completed trial  13/20 after       20 sec | tr score    0.162 | te score    0.186 | nnz      1
# completed trial  14/20 after       21 sec | tr score    0.157 | te score    0.246 | nnz      1
# completed trial  15/20 after       23 sec | tr score    0.167 | te score    0.149 | nnz      1
# completed trial  16/20 after       24 sec | tr score    0.166 | te score    0.177 | nnz      1
# completed trial  17/20 after       26 sec | tr score    0.119 | te score    0.287 | nnz      8
# completed trial  18/20 after       28 sec | tr score    0.121 | te score    0.174 | nnz     10
# completed trial  19/20 after       29 sec | tr score    0.169 | te score    0.211 | nnz      1
# completed trial  20/20 after       30 sec | tr score    0.110 | te score    0.209 | nnz      9
# Predicting stability with pre as predictors
# Fitting Lasso with 20 trials of 10-fold nested cross validation
# Selecting parameter 'alpha' based on grid search over 37 param values:
# 1e-12,3.16e-12,1e-11,...,3.16e+05,1e+06
# /cluster/tufts/hugheslab/miniconda2/envs/bdl2019f_readonly/lib/python3.6/site-packages/sklearn/linear_model/coordinate_descent.py:475: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 18178060.349909306, tolerance: 3640709.047393581
#   positive)
# /cluster/tufts/hugheslab/miniconda2/envs/bdl2019f_readonly/lib/python3.6/site-packages/sklearn/linear_model/coordinate_descent.py:475: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 11842235.694561481, tolerance: 3911352.703753089
#   positive)
# /cluster/tufts/hugheslab/miniconda2/envs/bdl2019f_readonly/lib/python3.6/site-packages/sklearn/linear_model/coordinate_descent.py:475: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 11434440.022490025, tolerance: 3640709.047393581
#   positive)
# /cluster/tufts/hugheslab/miniconda2/envs/bdl2019f_readonly/lib/python3.6/site-packages/sklearn/linear_model/coordinate_descent.py:475: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 5424624.09090066, tolerance: 1814718.2300637073
#   positive)
# /cluster/tufts/hugheslab/miniconda2/envs/bdl2019f_readonly/lib/python3.6/site-packages/sklearn/linear_model/coordinate_descent.py:475: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 3928761.9743070602, tolerance: 3644550.7173285196
#   positive)
# /cluster/tufts/hugheslab/miniconda2/envs/bdl2019f_readonly/lib/python3.6/site-packages/sklearn/linear_model/coordinate_descent.py:475: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 4282832.492781639, tolerance: 3846496.9564088746
#   positive)
# completed trial   1/20 after        3 sec | tr score 7470.070 | te score 15829.668 | nnz      0
# /cluster/tufts/hugheslab/miniconda2/envs/bdl2019f_readonly/lib/python3.6/site-packages/sklearn/linear_model/coordinate_descent.py:475: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 39300275.589224815, tolerance: 5989637.600868026
#   positive)
# /cluster/tufts/hugheslab/miniconda2/envs/bdl2019f_readonly/lib/python3.6/site-packages/sklearn/linear_model/coordinate_descent.py:475: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 19680827.38776779, tolerance: 5134289.809062208
#   positive)
# /cluster/tufts/hugheslab/miniconda2/envs/bdl2019f_readonly/lib/python3.6/site-packages/sklearn/linear_model/coordinate_descent.py:475: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 27839193.188617706, tolerance: 5857592.365083848
#   positive)
# /cluster/tufts/hugheslab/miniconda2/envs/bdl2019f_readonly/lib/python3.6/site-packages/sklearn/linear_model/coordinate_descent.py:475: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 62963504.58773422, tolerance: 5745662.870398623
#   positive)
# /cluster/tufts/hugheslab/miniconda2/envs/bdl2019f_readonly/lib/python3.6/site-packages/sklearn/linear_model/coordinate_descent.py:475: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 21801599.485894203, tolerance: 5989637.600868026
#   positive)
# /cluster/tufts/hugheslab/miniconda2/envs/bdl2019f_readonly/lib/python3.6/site-packages/sklearn/linear_model/coordinate_descent.py:475: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 28885745.607357025, tolerance: 5134289.809062208
#   positive)
# /cluster/tufts/hugheslab/miniconda2/envs/bdl2019f_readonly/lib/python3.6/site-packages/sklearn/linear_model/coordinate_descent.py:475: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 17511526.458946228, tolerance: 5857592.365083848
#   positive)
# /cluster/tufts/hugheslab/miniconda2/envs/bdl2019f_readonly/lib/python3.6/site-packages/sklearn/linear_model/coordinate_descent.py:475: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 8767724.322951317, tolerance: 5745662.870398623
#   positive)
# /cluster/tufts/hugheslab/miniconda2/envs/bdl2019f_readonly/lib/python3.6/site-packages/sklearn/linear_model/coordinate_descent.py:475: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 5543222.182171822, tolerance: 5060129.053965757
#   positive)
# completed trial   2/20 after        8 sec | tr score 8523.106 | te score 6254.889 | nnz      1
# /cluster/tufts/hugheslab/miniconda2/envs/bdl2019f_readonly/lib/python3.6/site-packages/sklearn/linear_model/coordinate_descent.py:475: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 1006714658.6648376, tolerance: 5314840.615667808
#   positive)
# /cluster/tufts/hugheslab/miniconda2/envs/bdl2019f_readonly/lib/python3.6/site-packages/sklearn/linear_model/coordinate_descent.py:475: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 260889578.51754045, tolerance: 5053423.35325343
#   positive)
# /cluster/tufts/hugheslab/miniconda2/envs/bdl2019f_readonly/lib/python3.6/site-packages/sklearn/linear_model/coordinate_descent.py:475: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 187304557.77798843, tolerance: 4942268.789034736
#   positive)
# /cluster/tufts/hugheslab/miniconda2/envs/bdl2019f_readonly/lib/python3.6/site-packages/sklearn/linear_model/coordinate_descent.py:475: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 15055630.521989822, tolerance: 5123812.094686089
#   positive)
# /cluster/tufts/hugheslab/miniconda2/envs/bdl2019f_readonly/lib/python3.6/site-packages/sklearn/linear_model/coordinate_descent.py:475: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 75022099.31521463, tolerance: 5314840.615667808
#   positive)
# /cluster/tufts/hugheslab/miniconda2/envs/bdl2019f_readonly/lib/python3.6/site-packages/sklearn/linear_model/coordinate_descent.py:475: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 25277949.476963997, tolerance: 5053423.35325343
#   positive)
# /cluster/tufts/hugheslab/miniconda2/envs/bdl2019f_readonly/lib/python3.6/site-packages/sklearn/linear_model/coordinate_descent.py:475: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 85111265.04872608, tolerance: 4942268.789034736
#   positive)
# /cluster/tufts/hugheslab/miniconda2/envs/bdl2019f_readonly/lib/python3.6/site-packages/sklearn/linear_model/coordinate_descent.py:475: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 5585258.6477127075, tolerance: 5123812.094686089
#   positive)
# /cluster/tufts/hugheslab/miniconda2/envs/bdl2019f_readonly/lib/python3.6/site-packages/sklearn/linear_model/coordinate_descent.py:475: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 28349577.31123066, tolerance: 5314840.615667808
#   positive)
# completed trial   3/20 after       13 sec | tr score 7925.297 | te score 11245.173 | nnz      1
# /cluster/tufts/hugheslab/miniconda2/envs/bdl2019f_readonly/lib/python3.6/site-packages/sklearn/linear_model/coordinate_descent.py:475: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 86784435.60413074, tolerance: 5956803.553420818
#   positive)
# /cluster/tufts/hugheslab/miniconda2/envs/bdl2019f_readonly/lib/python3.6/site-packages/sklearn/linear_model/coordinate_descent.py:475: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 100229571.6553564, tolerance: 3819186.305570624
#   positive)
# /cluster/tufts/hugheslab/miniconda2/envs/bdl2019f_readonly/lib/python3.6/site-packages/sklearn/linear_model/coordinate_descent.py:475: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 141534692.07890224, tolerance: 5334039.215684975
#   positive)
# /cluster/tufts/hugheslab/miniconda2/envs/bdl2019f_readonly/lib/python3.6/site-packages/sklearn/linear_model/coordinate_descent.py:475: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 67145251.69633389, tolerance: 5956803.553420818
#   positive)
# /cluster/tufts/hugheslab/miniconda2/envs/bdl2019f_readonly/lib/python3.6/site-packages/sklearn/linear_model/coordinate_descent.py:475: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 19720582.16350603, tolerance: 3819186.305570624
#   positive)
# /cluster/tufts/hugheslab/miniconda2/envs/bdl2019f_readonly/lib/python3.6/site-packages/sklearn/linear_model/coordinate_descent.py:475: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 15737171.90627098, tolerance: 5334039.215684975
#   positive)
# /cluster/tufts/hugheslab/miniconda2/envs/bdl2019f_readonly/lib/python3.6/site-packages/sklearn/linear_model/coordinate_descent.py:475: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 5838093.286870956, tolerance: 5334039.215684975
#   positive)
# completed trial   4/20 after       16 sec | tr score 8922.572 | te score 3904.712 | nnz      1
# /cluster/tufts/hugheslab/miniconda2/envs/bdl2019f_readonly/lib/python3.6/site-packages/sklearn/linear_model/coordinate_descent.py:475: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 84648153.22068024, tolerance: 5950927.2020908585
#   positive)
# /cluster/tufts/hugheslab/miniconda2/envs/bdl2019f_readonly/lib/python3.6/site-packages/sklearn/linear_model/coordinate_descent.py:475: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 409731338.34501696, tolerance: 5602685.3588771075
#   positive)
# /cluster/tufts/hugheslab/miniconda2/envs/bdl2019f_readonly/lib/python3.6/site-packages/sklearn/linear_model/coordinate_descent.py:475: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 130429966.08403492, tolerance: 5950927.2020908585
#   positive)
# /cluster/tufts/hugheslab/miniconda2/envs/bdl2019f_readonly/lib/python3.6/site-packages/sklearn/linear_model/coordinate_descent.py:475: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 20530796.951803207, tolerance: 5090748.517996832
#   positive)
# /cluster/tufts/hugheslab/miniconda2/envs/bdl2019f_readonly/lib/python3.6/site-packages/sklearn/linear_model/coordinate_descent.py:475: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 79677509.745718, tolerance: 5602685.3588771075
#   positive)
# /cluster/tufts/hugheslab/miniconda2/envs/bdl2019f_readonly/lib/python3.6/site-packages/sklearn/linear_model/coordinate_descent.py:475: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 37334277.49612236, tolerance: 5950927.2020908585
#   positive)
# /cluster/tufts/hugheslab/miniconda2/envs/bdl2019f_readonly/lib/python3.6/site-packages/sklearn/linear_model/coordinate_descent.py:475: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 7197928.393200874, tolerance: 5602685.3588771075
#   positive)
# completed trial   5/20 after       20 sec | tr score 8445.066 | te score 7358.107 | nnz      1
# /cluster/tufts/hugheslab/miniconda2/envs/bdl2019f_readonly/lib/python3.6/site-packages/sklearn/linear_model/coordinate_descent.py:475: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 20827329.321470737, tolerance: 4231966.720177575
#   positive)
# /cluster/tufts/hugheslab/miniconda2/envs/bdl2019f_readonly/lib/python3.6/site-packages/sklearn/linear_model/coordinate_descent.py:475: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 158549543.94048977, tolerance: 4521627.531800256
#   positive)
# /cluster/tufts/hugheslab/miniconda2/envs/bdl2019f_readonly/lib/python3.6/site-packages/sklearn/linear_model/coordinate_descent.py:475: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 24656148.46122074, tolerance: 5061559.173145756
#   positive)
# /cluster/tufts/hugheslab/miniconda2/envs/bdl2019f_readonly/lib/python3.6/site-packages/sklearn/linear_model/coordinate_descent.py:475: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 9656520.565990448, tolerance: 4521627.531800256
#   positive)
# /cluster/tufts/hugheslab/miniconda2/envs/bdl2019f_readonly/lib/python3.6/site-packages/sklearn/linear_model/coordinate_descent.py:475: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 76207247.39677572, tolerance: 5061559.173145756
#   positive)
# /cluster/tufts/hugheslab/miniconda2/envs/bdl2019f_readonly/lib/python3.6/site-packages/sklearn/linear_model/coordinate_descent.py:475: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 13823977.405944824, tolerance: 5061559.173145756
#   positive)
# completed trial   6/20 after       23 sec | tr score 8003.540 | te score 11064.891 | nnz      1
# /cluster/tufts/hugheslab/miniconda2/envs/bdl2019f_readonly/lib/python3.6/site-packages/sklearn/linear_model/coordinate_descent.py:475: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 132858719.9894371, tolerance: 5764952.98422884
#   positive)
# /cluster/tufts/hugheslab/miniconda2/envs/bdl2019f_readonly/lib/python3.6/site-packages/sklearn/linear_model/coordinate_descent.py:475: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 44064215.98135233, tolerance: 4982791.718949523
#   positive)
# /cluster/tufts/hugheslab/miniconda2/envs/bdl2019f_readonly/lib/python3.6/site-packages/sklearn/linear_model/coordinate_descent.py:475: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 121925901.18229485, tolerance: 3822142.3728052313
#   positive)
# /cluster/tufts/hugheslab/miniconda2/envs/bdl2019f_readonly/lib/python3.6/site-packages/sklearn/linear_model/coordinate_descent.py:475: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 39203027.16705513, tolerance: 5764952.98422884
#   positive)
# /cluster/tufts/hugheslab/miniconda2/envs/bdl2019f_readonly/lib/python3.6/site-packages/sklearn/linear_model/coordinate_descent.py:475: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 22234955.844717026, tolerance: 5502960.066561791
#   positive)
# /cluster/tufts/hugheslab/miniconda2/envs/bdl2019f_readonly/lib/python3.6/site-packages/sklearn/linear_model/coordinate_descent.py:475: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 9829058.409851551, tolerance: 4982791.718949523
#   positive)
# /cluster/tufts/hugheslab/miniconda2/envs/bdl2019f_readonly/lib/python3.6/site-packages/sklearn/linear_model/coordinate_descent.py:475: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 8524035.553718567, tolerance: 5502960.066561791
#   positive)
# /cluster/tufts/hugheslab/miniconda2/envs/bdl2019f_readonly/lib/python3.6/site-packages/sklearn/linear_model/coordinate_descent.py:475: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 4813990.698672771, tolerance: 3822142.3728052313
#   positive)
# completed trial   7/20 after       28 sec | tr score 8405.308 | te score 8778.598 | nnz      1
# /cluster/tufts/hugheslab/miniconda2/envs/bdl2019f_readonly/lib/python3.6/site-packages/sklearn/linear_model/coordinate_descent.py:475: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 642721900.2749219, tolerance: 6047277.254872908
#   positive)
# /cluster/tufts/hugheslab/miniconda2/envs/bdl2019f_readonly/lib/python3.6/site-packages/sklearn/linear_model/coordinate_descent.py:475: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 27831193.429758072, tolerance: 6003215.70568033
#   positive)
# /cluster/tufts/hugheslab/miniconda2/envs/bdl2019f_readonly/lib/python3.6/site-packages/sklearn/linear_model/coordinate_descent.py:475: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 640738751.2402167, tolerance: 5980205.879051107
#   positive)
# /cluster/tufts/hugheslab/miniconda2/envs/bdl2019f_readonly/lib/python3.6/site-packages/sklearn/linear_model/coordinate_descent.py:475: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 972328555.3277082, tolerance: 6142871.99661677
#   positive)
# /cluster/tufts/hugheslab/miniconda2/envs/bdl2019f_readonly/lib/python3.6/site-packages/sklearn/linear_model/coordinate_descent.py:475: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 82743505.76831627, tolerance: 5851374.281059089
#   positive)
# /cluster/tufts/hugheslab/miniconda2/envs/bdl2019f_readonly/lib/python3.6/site-packages/sklearn/linear_model/coordinate_descent.py:475: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 144672966.739398, tolerance: 6047277.254872908
#   positive)
# /cluster/tufts/hugheslab/miniconda2/envs/bdl2019f_readonly/lib/python3.6/site-packages/sklearn/linear_model/coordinate_descent.py:475: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 130833852.57845211, tolerance: 6003215.70568033
#   positive)
# /cluster/tufts/hugheslab/miniconda2/envs/bdl2019f_readonly/lib/python3.6/site-packages/sklearn/linear_model/coordinate_descent.py:475: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 136511569.31896353, tolerance: 5980205.879051107
#   positive)
# /cluster/tufts/hugheslab/miniconda2/envs/bdl2019f_readonly/lib/python3.6/site-packages/sklearn/linear_model/coordinate_descent.py:475: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 287792716.4801426, tolerance: 6142871.99661677
#   positive)
# /cluster/tufts/hugheslab/miniconda2/envs/bdl2019f_readonly/lib/python3.6/site-packages/sklearn/linear_model/coordinate_descent.py:475: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 17059758.192552567, tolerance: 5851374.281059089
#   positive)
# /cluster/tufts/hugheslab/miniconda2/envs/bdl2019f_readonly/lib/python3.6/site-packages/sklearn/linear_model/coordinate_descent.py:475: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 28215766.471269608, tolerance: 6047277.254872908
#   positive)
# /cluster/tufts/hugheslab/miniconda2/envs/bdl2019f_readonly/lib/python3.6/site-packages/sklearn/linear_model/coordinate_descent.py:475: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 15911023.802438736, tolerance: 6142871.99661677
#   positive)
# completed trial   8/20 after       33 sec | tr score 8434.565 | te score 5795.576 | nnz      1
# /cluster/tufts/hugheslab/miniconda2/envs/bdl2019f_readonly/lib/python3.6/site-packages/sklearn/linear_model/coordinate_descent.py:475: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 367638060.5435648, tolerance: 5156916.567105718
#   positive)
# /cluster/tufts/hugheslab/miniconda2/envs/bdl2019f_readonly/lib/python3.6/site-packages/sklearn/linear_model/coordinate_descent.py:475: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 136879243.80710602, tolerance: 5099501.782669748
#   positive)
# /cluster/tufts/hugheslab/miniconda2/envs/bdl2019f_readonly/lib/python3.6/site-packages/sklearn/linear_model/coordinate_descent.py:475: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 639300560.7178869, tolerance: 5207096.96663152
#   positive)
# /cluster/tufts/hugheslab/miniconda2/envs/bdl2019f_readonly/lib/python3.6/site-packages/sklearn/linear_model/coordinate_descent.py:475: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 19316061.253112793, tolerance: 5139160.009973341
#   positive)
# /cluster/tufts/hugheslab/miniconda2/envs/bdl2019f_readonly/lib/python3.6/site-packages/sklearn/linear_model/coordinate_descent.py:475: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 115587670.6758461, tolerance: 4246808.742745775
#   positive)
# /cluster/tufts/hugheslab/miniconda2/envs/bdl2019f_readonly/lib/python3.6/site-packages/sklearn/linear_model/coordinate_descent.py:475: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 130341270.77400684, tolerance: 4937046.755173574
#   positive)
# /cluster/tufts/hugheslab/miniconda2/envs/bdl2019f_readonly/lib/python3.6/site-packages/sklearn/linear_model/coordinate_descent.py:475: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 220251906.37490177, tolerance: 5156916.567105718
#   positive)
# /cluster/tufts/hugheslab/miniconda2/envs/bdl2019f_readonly/lib/python3.6/site-packages/sklearn/linear_model/coordinate_descent.py:475: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 26931556.519651413, tolerance: 5099501.782669748
#   positive)
# /cluster/tufts/hugheslab/miniconda2/envs/bdl2019f_readonly/lib/python3.6/site-packages/sklearn/linear_model/coordinate_descent.py:475: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 197036719.00622416, tolerance: 5207096.96663152
#   positive)
# /cluster/tufts/hugheslab/miniconda2/envs/bdl2019f_readonly/lib/python3.6/site-packages/sklearn/linear_model/coordinate_descent.py:475: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 110324541.10140228, tolerance: 5139160.009973341
#   positive)
# /cluster/tufts/hugheslab/miniconda2/envs/bdl2019f_readonly/lib/python3.6/site-packages/sklearn/linear_model/coordinate_descent.py:475: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 96049749.54793406, tolerance: 4246808.742745775
#   positive)
# /cluster/tufts/hugheslab/miniconda2/envs/bdl2019f_readonly/lib/python3.6/site-packages/sklearn/linear_model/coordinate_descent.py:475: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 32105192.87237835, tolerance: 4937046.755173574
#   positive)
# /cluster/tufts/hugheslab/miniconda2/envs/bdl2019f_readonly/lib/python3.6/site-packages/sklearn/linear_model/coordinate_descent.py:475: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 28305505.558128834, tolerance: 5156916.567105718
#   positive)
# /cluster/tufts/hugheslab/miniconda2/envs/bdl2019f_readonly/lib/python3.6/site-packages/sklearn/linear_model/coordinate_descent.py:475: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 6367667.4610004425, tolerance: 5207096.96663152
#   positive)
# /cluster/tufts/hugheslab/miniconda2/envs/bdl2019f_readonly/lib/python3.6/site-packages/sklearn/linear_model/coordinate_descent.py:475: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 11584230.265525818, tolerance: 5139160.009973341
#   positive)
# /cluster/tufts/hugheslab/miniconda2/envs/bdl2019f_readonly/lib/python3.6/site-packages/sklearn/linear_model/coordinate_descent.py:475: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 14213901.40195942, tolerance: 4246808.742745775
#   positive)
# completed trial   9/20 after       41 sec | tr score 8051.372 | te score 9734.052 | nnz      1
# /cluster/tufts/hugheslab/miniconda2/envs/bdl2019f_readonly/lib/python3.6/site-packages/sklearn/linear_model/coordinate_descent.py:475: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 20054084.651803493, tolerance: 4411720.944987731
#   positive)
# /cluster/tufts/hugheslab/miniconda2/envs/bdl2019f_readonly/lib/python3.6/site-packages/sklearn/linear_model/coordinate_descent.py:475: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 395596243.48525333, tolerance: 4852417.045970724
#   positive)
# ...
#   positive)
# /cluster/tufts/hugheslab/miniconda2/envs/bdl2019f_readonly/lib/python3.6/site-packages/sklearn/linear_model/coordinate_descent.py:475: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 76798760.14301908, tolerance: 4848708.5322798975
#   positive)
# /cluster/tufts/hugheslab/miniconda2/envs/bdl2019f_readonly/lib/python3.6/site-packages/sklearn/linear_model/coordinate_descent.py:475: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 21607928.809792638, tolerance: 4216732.5888521075
#   positive)
# completed trial  16/20 after      691 sec | tr score 5152.655 | te score 7769.486 | nnz     10
# /cluster/tufts/hugheslab/miniconda2/envs/bdl2019f_readonly/lib/python3.6/site-packages/sklearn/linear_model/coordinate_descent.py:475: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 201356262.38151103, tolerance: 5930294.032108501
#   positive)
# /cluster/tufts/hugheslab/miniconda2/envs/bdl2019f_readonly/lib/python3.6/site-packages/sklearn/linear_model/coordinate_descent.py:475: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 120954846.67889726, tolerance: 5672759.355750792
#   positive)
# /cluster/tufts/hugheslab/miniconda2/envs/bdl2019f_readonly/lib/python3.6/site-packages/sklearn/linear_model/coordinate_descent.py:475: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 106239637.78555477, tolerance: 5716283.833434389
#   positive)
# /cluster/tufts/hugheslab/miniconda2/envs/bdl2019f_readonly/lib/python3.6/site-packages/sklearn/linear_model/coordinate_descent.py:475: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 203606811.51713958, tolerance: 5758115.376551556
#   positive)
# /cluster/tufts/hugheslab/miniconda2/envs/bdl2019f_readonly/lib/python3.6/site-packages/sklearn/linear_model/coordinate_descent.py:475: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 233069360.61912927, tolerance: 5835466.223106697
#   positive)
# /cluster/tufts/hugheslab/miniconda2/envs/bdl2019f_readonly/lib/python3.6/site-packages/sklearn/linear_model/coordinate_descent.py:475: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 231018901.6606983, tolerance: 5167599.487243709
#   positive)
# /cluster/tufts/hugheslab/miniconda2/envs/bdl2019f_readonly/lib/python3.6/site-packages/sklearn/linear_model/coordinate_descent.py:475: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 90896135.38004562, tolerance: 5120584.511014599
#   positive)
# /cluster/tufts/hugheslab/miniconda2/envs/bdl2019f_readonly/lib/python3.6/site-packages/sklearn/linear_model/coordinate_descent.py:475: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 244222723.22614005, tolerance: 5821926.492191857
#   positive)
# /cluster/tufts/hugheslab/miniconda2/envs/bdl2019f_readonly/lib/python3.6/site-packages/sklearn/linear_model/coordinate_descent.py:475: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 45170722.25883803, tolerance: 3940653.800391901
#   positive)
# /cluster/tufts/hugheslab/miniconda2/envs/bdl2019f_readonly/lib/python3.6/site-packages/sklearn/linear_model/coordinate_descent.py:475: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 40796420.723406136, tolerance: 5930294.032108501
#   positive)
# /cluster/tufts/hugheslab/miniconda2/envs/bdl2019f_readonly/lib/python3.6/site-packages/sklearn/linear_model/coordinate_descent.py:475: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 66704213.8933208, tolerance: 5835466.223106697
#   positive)
# completed trial  17/20 after      738 sec | tr score 7311.637 | te score 5141.058 | nnz      2
# /cluster/tufts/hugheslab/miniconda2/envs/bdl2019f_readonly/lib/python3.6/site-packages/sklearn/linear_model/coordinate_descent.py:475: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 123897432.14088881, tolerance: 5486793.40845763
#   positive)
# /cluster/tufts/hugheslab/miniconda2/envs/bdl2019f_readonly/lib/python3.6/site-packages/sklearn/linear_model/coordinate_descent.py:475: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 56087177.18359222, tolerance: 3080563.679819741
#   positive)
# /cluster/tufts/hugheslab/miniconda2/envs/bdl2019f_readonly/lib/python3.6/site-packages/sklearn/linear_model/coordinate_descent.py:475: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 192697917.98896915, tolerance: 5847800.184064292
#   positive)
# /cluster/tufts/hugheslab/miniconda2/envs/bdl2019f_readonly/lib/python3.6/site-packages/sklearn/linear_model/coordinate_descent.py:475: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 58954026.14899482, tolerance: 5741659.746176842
#   positive)
# /cluster/tufts/hugheslab/miniconda2/envs/bdl2019f_readonly/lib/python3.6/site-packages/sklearn/linear_model/coordinate_descent.py:475: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 170384671.9635091, tolerance: 5869247.0514565
#   positive)
# /cluster/tufts/hugheslab/miniconda2/envs/bdl2019f_readonly/lib/python3.6/site-packages/sklearn/linear_model/coordinate_descent.py:475: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 215398792.67884463, tolerance: 5909040.2983179735
#   positive)
# /cluster/tufts/hugheslab/miniconda2/envs/bdl2019f_readonly/lib/python3.6/site-packages/sklearn/linear_model/coordinate_descent.py:475: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 221761805.17337576, tolerance: 5692332.750254598
#   positive)
# /cluster/tufts/hugheslab/miniconda2/envs/bdl2019f_readonly/lib/python3.6/site-packages/sklearn/linear_model/coordinate_descent.py:475: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 189149066.08257198, tolerance: 5764215.945679699
#   positive)
# /cluster/tufts/hugheslab/miniconda2/envs/bdl2019f_readonly/lib/python3.6/site-packages/sklearn/linear_model/coordinate_descent.py:475: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 125420862.5917741, tolerance: 5201881.625876622
#   positive)
# /cluster/tufts/hugheslab/miniconda2/envs/bdl2019f_readonly/lib/python3.6/site-packages/sklearn/linear_model/coordinate_descent.py:475: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 51863407.64161736, tolerance: 5486793.40845763
#   positive)
# /cluster/tufts/hugheslab/miniconda2/envs/bdl2019f_readonly/lib/python3.6/site-packages/sklearn/linear_model/coordinate_descent.py:475: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 53514747.11439091, tolerance: 5869247.0514565
#   positive)
# /cluster/tufts/hugheslab/miniconda2/envs/bdl2019f_readonly/lib/python3.6/site-packages/sklearn/linear_model/coordinate_descent.py:475: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 70259637.61243516, tolerance: 5909040.2983179735
#   positive)
# /cluster/tufts/hugheslab/miniconda2/envs/bdl2019f_readonly/lib/python3.6/site-packages/sklearn/linear_model/coordinate_descent.py:475: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 62355601.30551541, tolerance: 5692332.750254598
#   positive)
# /cluster/tufts/hugheslab/miniconda2/envs/bdl2019f_readonly/lib/python3.6/site-packages/sklearn/linear_model/coordinate_descent.py:475: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 26624383.717807174, tolerance: 5764215.945679699
#   positive)
# completed trial  18/20 after      796 sec | tr score 7060.113 | te score 6919.275 | nnz      2
# /cluster/tufts/hugheslab/miniconda2/envs/bdl2019f_readonly/lib/python3.6/site-packages/sklearn/linear_model/coordinate_descent.py:475: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 173786771.4602302, tolerance: 5316471.3700172305
#   positive)
# /cluster/tufts/hugheslab/miniconda2/envs/bdl2019f_readonly/lib/python3.6/site-packages/sklearn/linear_model/coordinate_descent.py:475: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 201235879.85113806, tolerance: 5471701.788631123
#   positive)
# /cluster/tufts/hugheslab/miniconda2/envs/bdl2019f_readonly/lib/python3.6/site-packages/sklearn/linear_model/coordinate_descent.py:475: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 66196271.29453054, tolerance: 4464063.987262491
#   positive)
# /cluster/tufts/hugheslab/miniconda2/envs/bdl2019f_readonly/lib/python3.6/site-packages/sklearn/linear_model/coordinate_descent.py:475: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 120067121.2969501, tolerance: 5210329.698851968
#   positive)
# /cluster/tufts/hugheslab/miniconda2/envs/bdl2019f_readonly/lib/python3.6/site-packages/sklearn/linear_model/coordinate_descent.py:475: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 46594173.5810917, tolerance: 5229149.5926524885
#   positive)
# /cluster/tufts/hugheslab/miniconda2/envs/bdl2019f_readonly/lib/python3.6/site-packages/sklearn/linear_model/coordinate_descent.py:475: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 145887010.11005697, tolerance: 5235910.737462799
#   positive)
# /cluster/tufts/hugheslab/miniconda2/envs/bdl2019f_readonly/lib/python3.6/site-packages/sklearn/linear_model/coordinate_descent.py:475: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 105936000.10198018, tolerance: 4779323.66945237
#   positive)
# /cluster/tufts/hugheslab/miniconda2/envs/bdl2019f_readonly/lib/python3.6/site-packages/sklearn/linear_model/coordinate_descent.py:475: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 115478778.70274016, tolerance: 5342343.370128725
#   positive)
# /cluster/tufts/hugheslab/miniconda2/envs/bdl2019f_readonly/lib/python3.6/site-packages/sklearn/linear_model/coordinate_descent.py:475: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 97253417.5461538, tolerance: 3210000.3557080682
#   positive)
# /cluster/tufts/hugheslab/miniconda2/envs/bdl2019f_readonly/lib/python3.6/site-packages/sklearn/linear_model/coordinate_descent.py:475: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 70726610.22701383, tolerance: 5316471.3700172305
#   positive)
# /cluster/tufts/hugheslab/miniconda2/envs/bdl2019f_readonly/lib/python3.6/site-packages/sklearn/linear_model/coordinate_descent.py:475: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 41977803.19810617, tolerance: 5471701.788631123
#   positive)
# completed trial  19/20 after      844 sec | tr score 5033.266 | te score 6381.034 | nnz     10
# /cluster/tufts/hugheslab/miniconda2/envs/bdl2019f_readonly/lib/python3.6/site-packages/sklearn/linear_model/coordinate_descent.py:475: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 196725166.7623014, tolerance: 5887562.3647219315
#   positive)
# /cluster/tufts/hugheslab/miniconda2/envs/bdl2019f_readonly/lib/python3.6/site-packages/sklearn/linear_model/coordinate_descent.py:475: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 189807275.5862304, tolerance: 5872299.97449722
#   positive)
# /cluster/tufts/hugheslab/miniconda2/envs/bdl2019f_readonly/lib/python3.6/site-packages/sklearn/linear_model/coordinate_descent.py:475: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 95357755.70013154, tolerance: 4111008.0053442745
#   positive)
# /cluster/tufts/hugheslab/miniconda2/envs/bdl2019f_readonly/lib/python3.6/site-packages/sklearn/linear_model/coordinate_descent.py:475: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 137403022.5513757, tolerance: 5860113.485215457
#   positive)
# /cluster/tufts/hugheslab/miniconda2/envs/bdl2019f_readonly/lib/python3.6/site-packages/sklearn/linear_model/coordinate_descent.py:475: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 167116129.86203915, tolerance: 5834200.187646756
#   positive)
# /cluster/tufts/hugheslab/miniconda2/envs/bdl2019f_readonly/lib/python3.6/site-packages/sklearn/linear_model/coordinate_descent.py:475: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 166423227.272275, tolerance: 5352234.998751108
#   positive)
# /cluster/tufts/hugheslab/miniconda2/envs/bdl2019f_readonly/lib/python3.6/site-packages/sklearn/linear_model/coordinate_descent.py:475: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 244253648.8706411, tolerance: 5258804.637739269
#   positive)
# /cluster/tufts/hugheslab/miniconda2/envs/bdl2019f_readonly/lib/python3.6/site-packages/sklearn/linear_model/coordinate_descent.py:475: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 93850558.30605969, tolerance: 5887562.3647219315
#   positive)
# /cluster/tufts/hugheslab/miniconda2/envs/bdl2019f_readonly/lib/python3.6/site-packages/sklearn/linear_model/coordinate_descent.py:475: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 72096117.98557782, tolerance: 5872299.97449722
#   positive)
# /cluster/tufts/hugheslab/miniconda2/envs/bdl2019f_readonly/lib/python3.6/site-packages/sklearn/linear_model/coordinate_descent.py:475: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 29728066.494773507, tolerance: 4111008.0053442745
#   positive)
# /cluster/tufts/hugheslab/miniconda2/envs/bdl2019f_readonly/lib/python3.6/site-packages/sklearn/linear_model/coordinate_descent.py:475: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 40744348.54871392, tolerance: 5860113.485215457
#   positive)
# /cluster/tufts/hugheslab/miniconda2/envs/bdl2019f_readonly/lib/python3.6/site-packages/sklearn/linear_model/coordinate_descent.py:475: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 75287001.1894759, tolerance: 5258804.637739269
#   positive)
# completed trial  20/20 after      897 sec | tr score 5059.151 | te score 6799.697 | nnz     11

# %%
labels = ['y pre', 'y pre + y mid', 'y pre + y mid + y post1', 'y pre + y mid + y post1 + y post2', 
          'static + y pre + y mid + y post1 +y post2']

for error in ['test_mae', 'test_mse']:
    f,axs = plt.subplots(3,1)
    for ax_idx, y_factor in enumerate(['lethality', 'mobility', 'stability']):
    #     y_perf_df = summary_perf_df.loc[summary_perf_df.y_column==y_factor, :].copy().reset_index(drop=True)
    #     sns.boxplot(x=y_perf_df['x_feature_nickname'], y=y_perf_df['test_mae'], ax=axs[ax_idx])
    #     axs[ax_idx].set_xlabel(y_perf_df['y_column'].unique()[0])
        x = np.asarray(range(len(labels)))/2
        y = np.asarray(summary_perf_df.loc[(summary_perf_df.y_column==y_factor)&
                                (summary_perf_df.percentile_across_trials==50), error])

        y_err_l = np.asarray(summary_perf_df.loc[(summary_perf_df.y_column==y_factor)&
                                (summary_perf_df.percentile_across_trials==5), error])

        y_err_u = np.asarray(summary_perf_df.loc[(summary_perf_df.y_column==y_factor)&
                                (summary_perf_df.percentile_across_trials==95), error])
        y_err = np.concatenate((y_err_l.reshape(-1,1), y_err_u.reshape(-1,1)), axis=1).T

        axs[ax_idx].errorbar(x=x, y=y, yerr=y_err, color="black", capsize=5,
                             linestyle="None",marker="s", markersize=10, 
                             mfc="black", mec="black")
        axs[ax_idx].set_xlim([-.3,2.3])
        axs[ax_idx].set_xticks(x)
        axs[ax_idx].set_xticklabels(labels, rotation=15)
        axs[ax_idx].set_title(y_factor)
        err_aka = error.replace('_', ' ').upper()
        axs[ax_idx].set_ylabel(err_aka)
    
        plt.suptitle('%s for predicting marksmanship performance in Post3'%err_aka)
        plt.subplots_adjust(hspace=0.45)
        f.set_size_inches(16.5, 12.5)
        f.savefig('%s.png'%error)
plt.show()

# %%
summary_perf_df.x_feature_nickname.unique()
# Out:
# array(['pre', 'pre+mid', 'pre+mid+post1', 'pre+mid+post1+post2',
#        'static+pre+mid+post1+post2', 'highfreq+pre+mid+post1+post2'],
#       dtype=object)

# %%
    y = np.asarray(summary_perf_df.loc[(summary_perf_df.y_column==y_factor)&
                            (summary_perf_df.percentile_across_trials==50), 'test_mae'])
    
    y_err_l = np.asarray(summary_perf_df.loc[(summary_perf_df.y_column==y_factor)&
                            (summary_perf_df.percentile_across_trials==5), 'test_mae'])
    
    y_err_u = np.asarray(summary_perf_df.loc[(summary_perf_df.y_column==y_factor)&
                            (summary_perf_df.percentile_across_trials==95), 'test_mae'])

# %%
np.concatenate((y_err_l.reshape(-1,1), y_err_u.reshape(-1,1)), axis=1).shape
# Out:
# (4, 2)

# %%
summary_perf_df
# Out:
#      y_column          x_feature_nickname  n_features  \
# 0   lethality                         pre           1
# 1   lethality                         pre           1
# 2   lethality                         pre           1
# 3   lethality                     pre+mid           2
# 4   lethality                     pre+mid           2
# 5   lethality                     pre+mid           2
# 6   lethality               pre+mid+post1           3
# 7   lethality               pre+mid+post1           3
# 8   lethality               pre+mid+post1           3
# 9   lethality         pre+mid+post1+post2           4
# 10  lethality         pre+mid+post1+post2           4
# 11  lethality         pre+mid+post1+post2           4
# 12  lethality  static+pre+mid+post1+post2          27
# 13  lethality  static+pre+mid+post1+post2          27
# 14  lethality  static+pre+mid+post1+post2          27
# 15   mobility                         pre           1
# 16   mobility                         pre           1
# 17   mobility                         pre           1
# 18   mobility                     pre+mid           2
# 19   mobility                     pre+mid           2
# 20   mobility                     pre+mid           2
# 21   mobility               pre+mid+post1           3
# 22   mobility               pre+mid+post1           3
# 23   mobility               pre+mid+post1           3
# 24   mobility         pre+mid+post1+post2           4
# 25   mobility         pre+mid+post1+post2           4
# 26   mobility         pre+mid+post1+post2           4
# 27   mobility  static+pre+mid+post1+post2          27
# 28   mobility  static+pre+mid+post1+post2          27
# 29   mobility  static+pre+mid+post1+post2          27
# 30  stability                         pre           1
# 31  stability                         pre           1
# 32  stability                         pre           1
# 33  stability                     pre+mid           2
# 34  stability                     pre+mid           2
# 35  stability                     pre+mid           2
# 36  stability               pre+mid+post1           3
# 37  stability               pre+mid+post1           3
# 38  stability               pre+mid+post1           3
# 39  stability         pre+mid+post1+post2           4
# 40  stability         pre+mid+post1+post2           4
# 41  stability         pre+mid+post1+post2           4
# 42  stability  static+pre+mid+post1+post2          27
# 43  stability  static+pre+mid+post1+post2          27
# 44  stability  static+pre+mid+post1+post2          27
#
#     percentile_across_trials     train_mse      test_mse    train_mae  \
# 0                          5  1.321108e+03  3.186857e+02    27.817846
# 1                         50  1.515085e+03  9.543238e+02    30.392921
# 2                         95  1.593467e+03  2.495162e+03    31.974804
# 3                          5  1.321108e+03  3.186857e+02    27.817846
# 4                         50  1.515085e+03  9.543238e+02    30.392921
# 5                         95  1.593467e+03  2.495162e+03    31.974804
# 6                          5  1.321108e+03  3.186857e+02    27.817846
# 7                         50  1.515085e+03  9.543238e+02    30.392921
# 8                         95  1.593467e+03  2.495162e+03    31.974804
# 9                          5  8.733777e+02  3.077968e+02    23.481576
# 10                        50  9.979174e+02  7.789694e+02    25.557330
# 11                        95  1.090363e+03  1.617399e+03    27.250431
# 12                         5  9.232437e+02  3.071796e+02    24.420460
# 13                        50  1.016022e+03  7.368619e+02    25.775529
# 14                        95  1.090143e+03  1.632369e+03    27.033468
# 15                         5  5.038321e-02  2.181342e-02     0.176036
# 16                        50  5.988217e-02  6.869406e-02     0.192630
# 17                        95  6.577059e-02  1.439683e-01     0.206895
# 18                         5  4.550727e-02  1.902825e-02     0.168010
# 19                        50  5.622063e-02  6.869406e-02     0.188188
# 20                        95  6.334426e-02  1.387575e-01     0.198799
# 21                         5  3.265937e-02  1.756882e-02     0.133056
# 22                        50  4.296485e-02  4.336375e-02     0.148799
# 23                        95  4.583823e-02  1.231268e-01     0.157628
# 24                         5  2.382914e-02  1.750442e-02     0.115778
# 25                        50  3.390277e-02  4.613450e-02     0.132944
# 26                        95  3.664521e-02  1.127334e-01     0.142726
# 27                         5  1.666189e-02  3.282297e-02     0.091983
# 28                        50  2.741702e-02  6.304650e-02     0.123485
# 29                        95  4.715129e-02  1.254165e-01     0.167481
# 30                         5  1.202794e+08  2.872854e+07  7705.155807
# 31                        50  1.388643e+08  7.990002e+07  8419.936364
# 32                        95  1.445172e+08  2.288467e+08  8836.429108
# 33                         5  8.091417e+07  1.455362e+07  6408.060009
# 34                        50  9.013847e+07  9.565278e+07  6688.651386
# 35                        95  1.001247e+08  1.620171e+08  7322.327030
# 36                         5  8.090084e+07  1.867161e+07  6413.719273
# 37                        50  8.923263e+07  1.008438e+08  6709.206976
# 38                        95  9.937118e+07  1.647396e+08  7338.713479
# 39                         5  6.738781e+07  2.441127e+07  6143.607976
# 40                        50  7.956611e+07  8.166565e+07  6387.195426
# 41                        95  8.586669e+07  2.136020e+08  6862.787848
# 42                         5  3.882540e+07  4.015583e+07  4320.993025
# 43                        50  8.109544e+07  1.007394e+08  6575.843833
# 44                        95  9.877051e+07  3.518429e+08  7314.171526
#
#         test_mae  train_size  test_size  ...  inner_split8_test_score  \
# 0      15.618902        40.0        5.0  ...                17.802198
# 1      26.740795        40.0        5.0  ...                26.810196
# 2      43.549713        40.0        5.0  ...                36.590243
# 3      15.618902        40.0        5.0  ...                17.802198
# 4      26.740795        40.0        5.0  ...                26.810196
# 5      43.549713        40.0        5.0  ...                36.590243
# 6      15.618902        40.0        5.0  ...                17.802198
# 7      26.740795        40.0        5.0  ...                26.810196
# 8      43.549713        40.0        5.0  ...                36.590243
# 9      13.034234        40.0        5.0  ...                13.166815
# 10     24.449420        40.0        5.0  ...                25.586174
# 11     35.661867        40.0        5.0  ...                39.173568
# 12     12.861312        40.0        5.0  ...                13.139107
# 13     24.318930        40.0        5.0  ...                26.703279
# 14     38.546305        40.0        5.0  ...                35.619757
# 15      0.120806        40.0        5.0  ...                 0.091308
# 16      0.220369        40.0        5.0  ...                 0.175469
# 17      0.331800        40.0        5.0  ...                 0.291959
# 18      0.122378        40.0        5.0  ...                 0.092860
# 19      0.220369        40.0        5.0  ...                 0.174391
# 20      0.316180        40.0        5.0  ...                 0.298351
# 21      0.095150        40.0        5.0  ...                 0.088255
# 22      0.177536        40.0        5.0  ...                 0.182161
# 23      0.272954        40.0        5.0  ...                 0.286873
# 24      0.112085        40.0        5.0  ...                 0.087290
# 25      0.154292        40.0        5.0  ...                 0.166568
# 26      0.267619        40.0        5.0  ...                 0.251105
# 27      0.133911        40.0        5.0  ...                 0.112447
# 28      0.209356        40.0        5.0  ...                 0.156030
# 29      0.292960        40.0        5.0  ...                 0.265295
# 30   4520.622950        40.0        5.0  ...              4470.573384
# 31   8328.534292        40.0        5.0  ...              7079.972223
# 32  12223.094563        40.0        5.0  ...             10477.857845
# 33   2595.443153        40.0        5.0  ...              2909.024150
# 34   7796.506726        40.0        5.0  ...              6065.172176
# 35  11380.024699        40.0        5.0  ...              9305.032396
# 36   3264.533963        40.0        5.0  ...              2860.084042
# 37   7768.536171        40.0        5.0  ...              6159.236550
# 38  11315.452919        40.0        5.0  ...              9683.863277
# 39   3813.383167        40.0        5.0  ...              2169.183695
# 40   7122.550806        40.0        5.0  ...              6131.505968
# 41  11273.957331        40.0        5.0  ...              9008.317220
# 42   4812.971713        40.0        5.0  ...              4185.725092
# 43   7804.712620        40.0        5.0  ...              6076.561415
# 44  14309.047707        40.0        5.0  ...              8490.402237
#
#     inner_split9_train_score  inner_split9_test_score  inner_min_train_score  \
# 0                  27.135841                17.370902              25.606434
# 1                  29.369544                34.314622              27.094981
# 2                  32.295786                46.872643              29.933038
# 3                  27.135841                17.370902              25.606434
# 4                  29.369544                34.314622              27.094981
# 5                  32.295786                46.872643              29.933038
# 6                  27.135841                17.370902              25.606434
# 7                  29.369544                34.314622              27.094981
# 8                  32.295786                46.872643              29.933038
# 9                  22.749606                17.436443              20.896122
# 10                 25.550715                27.473052              23.508868
# 11                 28.248420                39.019462              25.357789
# 12                 22.761897                16.351458              22.511943
# 13                 25.151009                30.867049              23.745126
# 14                 27.966719                40.656199              25.068675
# 15                  0.165270                 0.132880               0.159479
# 16                  0.194363                 0.181986               0.172338
# 17                  0.207167                 0.356807               0.193892
# 18                  0.164800                 0.132322               0.149724
# 19                  0.184478                 0.181929               0.166103
# 20                  0.206369                 0.356807               0.188800
# 21                  0.120562                 0.060324               0.111744
# 22                  0.146363                 0.152380               0.130896
# 23                  0.165072                 0.315775               0.142067
# 24                  0.108239                 0.068252               0.102297
# 25                  0.128951                 0.148291               0.111886
# 26                  0.149827                 0.275968               0.128965
# 27                  0.097324                 0.064673               0.067146
# 28                  0.124720                 0.145080               0.108087
# 29                  0.167319                 0.331037               0.151541
# 30               6524.226717              4006.122638            6128.229997
# 31               8368.023006              8806.584395            7242.645319
# 32               9170.299570             20873.225561            7841.976636
# 33               6103.489840              2252.106486            5783.514464
# 34               6774.776657              7472.472896            6202.645849
# 35               7285.126260             17132.588140            6515.459665
# 36               6072.485056              2199.164409            5776.602555
# 37               6774.776657              7551.897893            6094.542764
# 38               7287.176663             16927.559870            6799.232911
# 39               5586.213106              1518.578865            5586.213106
# 40               6532.615962              7745.279465            5841.429311
# 41               7049.808747             15378.413450            6303.495501
# 42               4436.374751              2383.755959            3642.208642
# 43               5859.537927              7944.498348            5748.249752
# 44               7411.794645             16529.479339            6618.844792
#
#     inner_min_test_score  inner_max_train_score  inner_max_test_score  \
# 0               8.697593              29.498447             43.147337
# 1              13.398828              32.664739             49.700740
# 2              21.081992              33.971182             70.306873
# 3               8.697593              29.498447             43.147337
# 4              13.398828              32.664739             49.700740
# 5              21.081992              33.971182             70.306873
# 6               8.697593              29.498447             43.147337
# 7              13.398828              32.664739             49.700740
# 8              21.081992              33.971182             70.306873
# 9               6.485544              24.555785             34.350546
# 10             11.913985              26.810381             42.164663
# 11             19.254293              28.536636             60.488889
# 12              5.207820              25.232396             35.747308
# 13             10.782198              27.151899             42.968595
# 14             18.428173              28.263993             60.975631
# 15              0.034677               0.184861              0.288677
# 16              0.088713               0.205480              0.317083
# 17              0.127609               0.221165              0.395295
# 18              0.034677               0.175468              0.293463
# 19              0.090002               0.199196              0.320269
# 20              0.120746               0.213592              0.427303
# 21              0.032259               0.141965              0.233124
# 22              0.061189               0.159122              0.316155
# 23              0.096669               0.169699              0.395493
# 24              0.031720               0.120865              0.217385
# 25              0.060786               0.142044              0.270519
# 26              0.095164               0.152910              0.352226
# 27              0.038749               0.097324              0.239343
# 28              0.066976               0.129326              0.295894
# 29              0.105355               0.176764              0.346746
# 30           1791.010023            8291.646267          13400.654947
# 31           3899.719775            9027.964013          16605.176668
# 32           5279.188371            9346.760588          21700.533887
# 33           1413.968484            6816.289343          10667.780561
# 34           2329.630095            7183.969876          12540.165236
# 35           4272.162622            7722.607327          19837.052675
# 36           1723.493675            6753.197212          11206.580797
# 37           2697.158375            7174.106125          12788.903574
# 38           3895.997337            7761.612663          20050.483848
# 39           1188.419273            6608.912917          11104.671589
# 40           2414.355067            6891.169603          12783.579438
# 41           3808.549559            7309.328674          19462.111360
# 42           1303.911509            4655.973114          12312.676898
# 43           2735.422721            6978.705641          13037.498396
# 44           4361.327390            7669.927022          19973.948411
#
#     outer_model_bias  outer_model_num_nonzero_coef  \
# 0         140.851809                          0.00
# 1         143.069514                          0.00
# 2         144.663852                          0.00
# 3         140.851809                          0.00
# 4         143.069514                          0.00
# 5         144.663852                          0.00
# 6         140.851809                          0.00
# 7         143.069514                          0.00
# 8         144.663852                          0.00
# 9         140.851809                          1.00
# 10        143.069514                          1.00
# 11        144.663852                          2.05
# 12        140.851809                          1.00
# 13        143.069514                          2.00
# 14        144.663852                          2.05
# 15          0.911100                          0.00
# 16          0.941719                          0.00
# 17          0.962222                          1.00
# 18          0.911100                          0.00
# 19          0.941719                          2.00
# 20          0.962222                          2.00
# 21          0.911100                          2.00
# 22          0.941719                          3.00
# 23          0.962222                          3.00
# 24          0.911100                          2.00
# 25          0.941719                          4.00
# 26          0.962222                          4.00
# 27          0.911100                          1.00
# 28          0.941719                          7.50
# 29          0.962222                         13.20
# 30      19502.607544                          0.95
# 31      20269.642500                          1.00
# 32      20827.453244                          1.00
# 33      19502.607544                          1.00
# 34      20269.642500                          1.00
# 35      20827.453244                          2.00
# 36      19502.607544                          1.00
# 37      20269.642500                          2.00
# 38      20827.453244                          3.00
# 39      19502.607544                          2.00
# 40      20269.642500                          3.00
# 41      20827.453244                          4.00
# 42      19502.607544                          2.00
# 43      20269.642500                          2.50
# 44      20827.453244                         11.20
#
#     outer_model_best_param__regressor__alpha
# 0                               9.658114e+00
# 1                               1.000000e+01
# 2                               3.162278e+01
# 3                               1.000000e+01
# 4                               1.000000e+01
# 5                               3.162278e+01
# 6                               1.000000e+01
# 7                               3.162278e+01
# 8                               3.162278e+01
# 9                               3.162278e+00
# 10                              1.000000e+01
# 11                              1.000000e+01
# 12                              1.000000e+01
# 13                              1.000000e+01
# 14                              1.000000e+01
# 15                              1.000000e-12
# 16                              1.000000e-01
# 17                              1.000000e-01
# 18                              3.004214e-03
# 19                              2.081139e-02
# 20                              1.000000e-01
# 21                              9.500000e-07
# 22                              3.162278e-03
# 23                              1.000000e-02
# 24                              1.000000e-12
# 25                              1.000000e-02
# 26                              3.162278e-02
# 27                              1.000000e-02
# 28                              3.162278e-02
# 29                              1.000000e-01
# 30                              1.000000e-12
# 31                              3.162278e+02
# 32                              1.108114e+03
# 33                              3.162278e+02
# 34                              1.000000e+03
# 35                              1.000000e+03
# 36                              9.500000e+02
# 37                              1.000000e+03
# 38                              1.108114e+03
# 39                              9.658114e+02
# 40                              1.000000e+03
# 41                              1.000000e+03
# 42                              9.658114e+02
# 43                              3.162278e+03
# 44                              3.162278e+03
#
# [45 rows x 41 columns]

# %%
summary_perf_df.columns
# Out:
# Index(['y_column', 'x_feature_nickname', 'n_features',
#        'percentile_across_trials', 'train_mse', 'test_mse', 'train_mae',
#        'test_mae', 'train_size', 'test_size', 'outer_train_score',
#        'outer_test_score', 'inner_mean_train_score', 'inner_mean_test_score',
#        'inner_split0_train_score', 'inner_split0_test_score',
#        'inner_split1_train_score', 'inner_split1_test_score',
#        'inner_split2_train_score', 'inner_split2_test_score',
#        'inner_min_train_score', 'inner_min_test_score',
#        'inner_max_train_score', 'inner_max_test_score', 'outer_model_bias',
#        'outer_model_num_nonzero_coef',
#        'outer_model_best_param__regressor__alpha'],
#       dtype='object')

# %%
np.logspace(-5, 5, 5)
# Out:
# array([1.00000000e-05, 3.16227766e-03, 1.00000000e+00, 3.16227766e+02,
#        1.00000000e+05])
